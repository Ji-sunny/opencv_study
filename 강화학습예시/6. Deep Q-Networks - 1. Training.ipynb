# %%
"""
  TensorFlow translation of the torch example found here (written by SeanNaren).
  https://github.com/SeanNaren/TorchQLearningExample
  Original keras example found here (written by Eder Santana).
  https://gist.github.com/EderSantana/c7222daa328f0e885093#file-qlearn-py-L164
  The agent plays a game of catch. Fruits drop from the sky and the agent can choose the actions
  left/stay/right to catch the fruit before it reaches the ground.
"""

# import tensorflow as tf
import tensorflow.compat.v1 as tf 
tf.disable_v2_behavior()
import numpy as np
import random
import math
import os

# Parameters
epsilon = 1  # The probability of choosing a random action (in training). This decays as iterations increase. (0 to 1)
epsilonMinimumValue = 0.001 # The minimum value we want epsilon to reach in training. (0 to 1)
nbActions = 3 # The number of actions. Since we only have left/stay/right that means 3 actions.
epoch = 1001 # The number of games we want the system to run for.
hiddenSize = 100 # Number of neurons in the hidden layers.
maxMemory = 500 # How large should the memory be (where it stores its past experiences).
batchSize = 50 # The mini-batch size for training. Samples are randomly taken from memory till mini-batch size.
gridSize = 10 # The size of the grid that the agent is going to play the game on.
nbStates = gridSize * gridSize # We eventually flatten to a 1d tensor to feed the network.
discount = 0.9 # The discount is used to force the network to choose states that lead to the reward quicker (0 to 1)  
learningRate = 0.2 # Learning Rate for Stochastic Gradient Descent (our optimizer).

# Create the base model.
X = tf.placeholder(tf.float32, [None, nbStates])
W1 = tf.Variable(tf.truncated_normal([nbStates, hiddenSize], stddev=1.0 / math.sqrt(float(nbStates))))
b1 = tf.Variable(tf.truncated_normal([hiddenSize], stddev=0.01))  
input_layer = tf.nn.relu(tf.matmul(X, W1) + b1)
W2 = tf.Variable(tf.truncated_normal([hiddenSize, hiddenSize],stddev=1.0 / math.sqrt(float(hiddenSize))))
b2 = tf.Variable(tf.truncated_normal([hiddenSize], stddev=0.01))
hidden_layer = tf.nn.relu(tf.matmul(input_layer, W2) + b2)
W3 = tf.Variable(tf.truncated_normal([hiddenSize, nbActions],stddev=1.0 / math.sqrt(float(hiddenSize))))
b3 = tf.Variable(tf.truncated_normal([nbActions], stddev=0.01))
output_layer = tf.matmul(hidden_layer, W3) + b3

# True labels
Y = tf.placeholder(tf.float32, [None, nbActions])

# Mean squared error cost function
cost = tf.reduce_sum(tf.square(Y-output_layer)) / (2*batchSize)

# Stochastic Gradient Decent Optimizer
optimizer = tf.train.GradientDescentOptimizer(learningRate).minimize(cost)


# Helper function: Chooses a random value between the two boundaries.
def randf(s, e):
    return (float(random.randrange(0, (e - s) * 9999)) / 10000) + s;


# The environment: Handles interactions and contains the state of the environment
class CatchEnvironment():
    def __init__(self, gridSize):
        self.gridSize = gridSize
        self.nbStates = self.gridSize * self.gridSize
        self.state = np.empty(3, dtype = np.uint8) 

#   Returns the state of the environment.
    def observe(self):
        canvas = self.drawState()
        canvas = np.reshape(canvas, (-1,self.nbStates))
        return canvas

    def drawState(self):
        canvas = np.zeros((self.gridSize, self.gridSize))
        canvas[self.state[0]-1, self.state[1]-1] = 1  # Draw the fruit.
        # Draw the basket. The basket takes the adjacent two places to the position of basket.
        canvas[self.gridSize-1, self.state[2] -1 - 1] = 1
        canvas[self.gridSize-1, self.state[2] -1] = 1
        canvas[self.gridSize-1, self.state[2] -1 + 1] = 1    
        return canvas        

#   Resets the environment. Randomly initialise the fruit position (always at the top to begin with) and bucket.
    def reset(self): 
        initialFruitColumn = random.randrange(1, self.gridSize + 1)
        initialBucketPosition = random.randrange(2, self.gridSize + 1 - 1)
        self.state = np.array([1, initialFruitColumn, initialBucketPosition]) 
        return self.getState()

    def getState(self):
        stateInfo = self.state
        fruit_row = stateInfo[0]
        fruit_col = stateInfo[1]
        basket = stateInfo[2]
        return fruit_row, fruit_col, basket

#   Returns the award that the agent has gained for being in the current environment state.
    def getReward(self):
        fruitRow, fruitColumn, basket = self.getState()
        if (fruitRow == self.gridSize - 1):  # If the fruit has reached the bottom.
            if (abs(fruitColumn - basket) <= 1): # Check if the basket caught the fruit.
                return 1
            else:
                return -1
        else:
            return 0

    def isGameOver(self):
        if (self.state[0] == self.gridSize - 1): 
            return True 
        else: 
            return False 

    def updateState(self, action):
        if (action == 1):
            action = -1
        elif (action == 2):
            action = 0
        else:
            action = 1
        fruitRow, fruitColumn, basket = self.getState()
        newBasket = min(max(2, basket + action), self.gridSize - 1) # The min/max prevents the basket from moving out of the grid.
        fruitRow = fruitRow + 1  # The fruit is falling by 1 every action.
        self.state = np.array([fruitRow, fruitColumn, newBasket])

#   Action can be 1 (move left) or 2 (move right)
    def act(self, action):
        self.updateState(action)
        reward = self.getReward()
        gameOver = self.isGameOver()
        return self.observe(), reward, gameOver, self.getState()   # For purpose of the visual, I also return the state.


# The memory: Handles the internal memory that we add experiences that occur based on agent's actions,
# and creates batches of experiences based on the mini-batch size for training.
class ReplayMemory:
    def __init__(self, gridSize, maxMemory, discount):
        self.maxMemory = maxMemory
        self.gridSize = gridSize
        self.nbStates = self.gridSize * self.gridSize
        self.discount = discount
        canvas = np.zeros((self.gridSize, self.gridSize))
        canvas = np.reshape(canvas, (-1,self.nbStates))
        self.inputState = np.empty((self.maxMemory, 100), dtype = np.float32)
        self.actions = np.zeros(self.maxMemory, dtype = np.uint8)
        self.nextState = np.empty((self.maxMemory, 100), dtype = np.float32)
        self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
        self.rewards = np.empty(self.maxMemory, dtype = np.int8) 
        self.count = 0
        self.current = 0

#   Appends the experience to the memory.
    def remember(self, currentState, action, reward, nextState, gameOver):
        self.actions[self.current] = action
        self.rewards[self.current] = reward
        self.inputState[self.current, ...] = currentState
        self.nextState[self.current, ...] = nextState
        self.gameOver[self.current] = gameOver
        self.count = max(self.count, self.current + 1)
        self.current = (self.current + 1) % self.maxMemory

    def getBatch(self, model, batchSize, nbActions, nbStates, sess, X):
    
        # We check to see if we have enough memory inputs to make an entire batch, if not we create the biggest
        # batch we can (at the beginning of training we will not have enough experience to fill a batch).
        memoryLength = self.count
        chosenBatchSize = min(batchSize, memoryLength)

        inputs = np.zeros((chosenBatchSize, nbStates))
        targets = np.zeros((chosenBatchSize, nbActions))

        # Fill the inputs and targets up.
        for i in range(chosenBatchSize):
            if memoryLength == 1:
                memoryLength = 2
            # Choose a random memory experience to add to the batch.
            randomIndex = random.randrange(1, memoryLength)
            current_inputState = np.reshape(self.inputState[randomIndex], (1, 100))

            target = sess.run(model, feed_dict={X: current_inputState})

            current_nextState =  np.reshape(self.nextState[randomIndex], (1, 100))
            current_outputs = sess.run(model, feed_dict={X: current_nextState})      

            # Gives us Q_sa, the max q for the next state.
            nextStateMaxQ = np.amax(current_outputs)
            if (self.gameOver[randomIndex] == True):
                target[0, [self.actions[randomIndex]-1]] = self.rewards[randomIndex]
            else:
                # reward + discount(gamma) * max_a' Q(s',a')
                # We are setting the Q-value for the action to  r + gamma*max a' Q(s', a'). The rest stay the same
                # to give an error of 0 for those outputs.
                target[0, [self.actions[randomIndex]-1]] = self.rewards[randomIndex] + self.discount * nextStateMaxQ

            # Update the inputs and targets.
            inputs[i] = current_inputState
            targets[i] = target

        return inputs, targets

    
def main(_):
    print("Training new model")

    # Define Environment
    env = CatchEnvironment(gridSize)

    # Define Replay Memory
    memory = ReplayMemory(gridSize, maxMemory, discount)

    # Add ops to save and restore all the variables.
    saver = tf.train.Saver()
  
    winCount = 0
    with tf.Session() as sess:   
        tf.initialize_all_variables().run() 

        for i in range(epoch):
            # Initialize the environment.
            err = 0
            env.reset()

            isGameOver = False

            # The initial state of the environment.
            currentState = env.observe()

            while (isGameOver != True):
                action = -9999  # action initilization
                # Decides if we should choose a random action, or an action from the policy network.
                global epsilon
                if (randf(0, 1) <= epsilon):
                    action = random.randrange(1, nbActions+1)
                else:          
                    # Forward the current state through the network.
                    q = sess.run(output_layer, feed_dict={X: currentState})          
                    # Find the max index (the chosen action).
                    index = q.argmax()
                    action = index + 1     

                # Decay the epsilon by multiplying by 0.999, not allowing it to go below a certain threshold.
                if (epsilon > epsilonMinimumValue):
                    epsilon = epsilon * 0.999

                nextState, reward, gameOver, stateInfo = env.act(action)

                if (reward == 1):
                    winCount = winCount + 1

                memory.remember(currentState, action, reward, nextState, gameOver)

                # Update the current state and if the game is over.
                currentState = nextState
                isGameOver = gameOver

                # We get a batch of training data to train the model.
                inputs, targets = memory.getBatch(output_layer, batchSize, nbActions, nbStates, sess, X)

                # Train the network which returns the error.
                _, loss = sess.run([optimizer, cost], feed_dict={X: inputs, Y: targets})  
                err = err + loss

            print("Epoch " + str(i) + ": err = " + str(err) + ": Win count = " + str(winCount) + " Win ratio = " + str(float(winCount)/float(i+1)*100))
        # Save the variables to disk.
        save_path = saver.save(sess, os.getcwd()+"/model.ckpt")
        print("Model saved in file: %s" % save_path)

if __name__ == '__main__':
    tf.app.run()
# Out:
# Training new model
# Epoch 0: err = nan: Win count = 0 Win ratio = 0.0
# Epoch 1: err = nan: Win count = 0 Win ratio = 0.0
# Epoch 2: err = nan: Win count = 1 Win ratio = 33.33333333333333
# Epoch 3: err = nan: Win count = 1 Win ratio = 25.0
# Epoch 4: err = nan: Win count = 2 Win ratio = 40.0
# Epoch 5: err = nan: Win count = 2 Win ratio = 33.33333333333333
# Epoch 6: err = nan: Win count = 2 Win ratio = 28.57142857142857
# Epoch 7: err = nan: Win count = 2 Win ratio = 25.0
# Epoch 8: err = nan: Win count = 2 Win ratio = 22.22222222222222
# Epoch 9: err = nan: Win count = 2 Win ratio = 20.0
# Epoch 10: err = nan: Win count = 2 Win ratio = 18.181818181818183
# Epoch 11: err = nan: Win count = 2 Win ratio = 16.666666666666664
# Epoch 12: err = nan: Win count = 2 Win ratio = 15.384615384615385
# Epoch 13: err = nan: Win count = 2 Win ratio = 14.285714285714285
# Epoch 14: err = nan: Win count = 2 Win ratio = 13.333333333333334
# Epoch 15: err = nan: Win count = 3 Win ratio = 18.75
# Epoch 16: err = nan: Win count = 3 Win ratio = 17.647058823529413
# Epoch 17: err = nan: Win count = 3 Win ratio = 16.666666666666664
# Epoch 18: err = nan: Win count = 3 Win ratio = 15.789473684210526
# Epoch 19: err = nan: Win count = 3 Win ratio = 15.0
# Epoch 20: err = nan: Win count = 4 Win ratio = 19.047619047619047
# Epoch 21: err = nan: Win count = 4 Win ratio = 18.181818181818183
# Epoch 22: err = nan: Win count = 4 Win ratio = 17.391304347826086
# Epoch 23: err = nan: Win count = 4 Win ratio = 16.666666666666664
# Epoch 24: err = nan: Win count = 5 Win ratio = 20.0
# Epoch 25: err = nan: Win count = 5 Win ratio = 19.230769230769234
# Epoch 26: err = nan: Win count = 5 Win ratio = 18.51851851851852
# Epoch 27: err = nan: Win count = 6 Win ratio = 21.428571428571427
# Epoch 28: err = nan: Win count = 7 Win ratio = 24.137931034482758
# Epoch 29: err = nan: Win count = 7 Win ratio = 23.333333333333332
# Epoch 30: err = nan: Win count = 7 Win ratio = 22.58064516129032
# Epoch 31: err = nan: Win count = 7 Win ratio = 21.875
# Epoch 32: err = nan: Win count = 7 Win ratio = 21.21212121212121
# Epoch 33: err = nan: Win count = 7 Win ratio = 20.588235294117645
# Epoch 34: err = nan: Win count = 7 Win ratio = 20.0
# Epoch 35: err = nan: Win count = 7 Win ratio = 19.444444444444446
# Epoch 36: err = nan: Win count = 7 Win ratio = 18.91891891891892
# Epoch 37: err = nan: Win count = 7 Win ratio = 18.421052631578945
# Epoch 38: err = nan: Win count = 7 Win ratio = 17.94871794871795
# Epoch 39: err = nan: Win count = 7 Win ratio = 17.5
# Epoch 40: err = nan: Win count = 7 Win ratio = 17.073170731707318
# Epoch 41: err = nan: Win count = 7 Win ratio = 16.666666666666664
# Epoch 42: err = nan: Win count = 7 Win ratio = 16.27906976744186
# Epoch 43: err = nan: Win count = 7 Win ratio = 15.909090909090908
# Epoch 44: err = nan: Win count = 8 Win ratio = 17.77777777777778
# Epoch 45: err = nan: Win count = 9 Win ratio = 19.565217391304348
# Epoch 46: err = nan: Win count = 9 Win ratio = 19.148936170212767
# Epoch 47: err = nan: Win count = 9 Win ratio = 18.75
# Epoch 48: err = nan: Win count = 10 Win ratio = 20.408163265306122
# Epoch 49: err = nan: Win count = 10 Win ratio = 20.0
# Epoch 50: err = nan: Win count = 11 Win ratio = 21.568627450980394
# Epoch 51: err = nan: Win count = 11 Win ratio = 21.153846153846153
# Epoch 52: err = nan: Win count = 11 Win ratio = 20.754716981132077
# Epoch 53: err = nan: Win count = 11 Win ratio = 20.37037037037037
# Epoch 54: err = nan: Win count = 12 Win ratio = 21.818181818181817
# Epoch 55: err = nan: Win count = 12 Win ratio = 21.428571428571427
# Epoch 56: err = nan: Win count = 12 Win ratio = 21.052631578947366
# Epoch 57: err = nan: Win count = 13 Win ratio = 22.413793103448278
# Epoch 58: err = nan: Win count = 14 Win ratio = 23.728813559322035
# Epoch 59: err = nan: Win count = 14 Win ratio = 23.333333333333332
# Epoch 60: err = nan: Win count = 15 Win ratio = 24.59016393442623
# Epoch 61: err = nan: Win count = 15 Win ratio = 24.193548387096776
# Epoch 62: err = nan: Win count = 15 Win ratio = 23.809523809523807
# Epoch 63: err = nan: Win count = 15 Win ratio = 23.4375
# Epoch 64: err = nan: Win count = 16 Win ratio = 24.615384615384617
# Epoch 65: err = nan: Win count = 17 Win ratio = 25.757575757575758
# Epoch 66: err = nan: Win count = 17 Win ratio = 25.37313432835821
# Epoch 67: err = nan: Win count = 17 Win ratio = 25.0
# Epoch 68: err = nan: Win count = 17 Win ratio = 24.637681159420293
# Epoch 69: err = nan: Win count = 17 Win ratio = 24.285714285714285
# Epoch 70: err = nan: Win count = 17 Win ratio = 23.943661971830984
# Epoch 71: err = nan: Win count = 17 Win ratio = 23.61111111111111
# Epoch 72: err = nan: Win count = 17 Win ratio = 23.28767123287671
# Epoch 73: err = nan: Win count = 18 Win ratio = 24.324324324324326
# Epoch 74: err = nan: Win count = 19 Win ratio = 25.333333333333336
# Epoch 75: err = nan: Win count = 19 Win ratio = 25.0
# Epoch 76: err = nan: Win count = 19 Win ratio = 24.675324675324674
# Epoch 77: err = nan: Win count = 19 Win ratio = 24.358974358974358
# Epoch 78: err = nan: Win count = 20 Win ratio = 25.31645569620253
# Epoch 79: err = nan: Win count = 21 Win ratio = 26.25
# Epoch 80: err = nan: Win count = 21 Win ratio = 25.925925925925924
# Epoch 81: err = nan: Win count = 22 Win ratio = 26.82926829268293
# Epoch 82: err = nan: Win count = 22 Win ratio = 26.506024096385545
# Epoch 83: err = nan: Win count = 22 Win ratio = 26.190476190476193
# Epoch 84: err = nan: Win count = 23 Win ratio = 27.058823529411764
# Epoch 85: err = nan: Win count = 23 Win ratio = 26.744186046511626
# Epoch 86: err = nan: Win count = 23 Win ratio = 26.436781609195403
# Epoch 87: err = nan: Win count = 24 Win ratio = 27.27272727272727
# Epoch 88: err = nan: Win count = 24 Win ratio = 26.96629213483146
# Epoch 89: err = nan: Win count = 25 Win ratio = 27.77777777777778
# Epoch 90: err = nan: Win count = 25 Win ratio = 27.472527472527474
# Epoch 91: err = nan: Win count = 25 Win ratio = 27.173913043478258
# Epoch 92: err = nan: Win count = 26 Win ratio = 27.956989247311824
# Epoch 93: err = nan: Win count = 27 Win ratio = 28.723404255319153
# Epoch 94: err = nan: Win count = 27 Win ratio = 28.421052631578945
# Epoch 95: err = nan: Win count = 27 Win ratio = 28.125
# Epoch 96: err = nan: Win count = 28 Win ratio = 28.865979381443296
# Epoch 97: err = nan: Win count = 28 Win ratio = 28.57142857142857
# Epoch 98: err = nan: Win count = 28 Win ratio = 28.28282828282828
# Epoch 99: err = nan: Win count = 28 Win ratio = 28.000000000000004
# Epoch 100: err = nan: Win count = 28 Win ratio = 27.722772277227726
# Epoch 101: err = nan: Win count = 28 Win ratio = 27.450980392156865
# Epoch 102: err = nan: Win count = 29 Win ratio = 28.155339805825243
# Epoch 103: err = nan: Win count = 29 Win ratio = 27.884615384615387
# Epoch 104: err = nan: Win count = 30 Win ratio = 28.57142857142857
# Epoch 105: err = nan: Win count = 30 Win ratio = 28.30188679245283
# Epoch 106: err = nan: Win count = 30 Win ratio = 28.037383177570092
# Epoch 107: err = nan: Win count = 31 Win ratio = 28.703703703703702
# Epoch 108: err = nan: Win count = 31 Win ratio = 28.440366972477065
# Epoch 109: err = nan: Win count = 31 Win ratio = 28.18181818181818
# Epoch 110: err = nan: Win count = 31 Win ratio = 27.927927927927925
# Epoch 111: err = nan: Win count = 32 Win ratio = 28.57142857142857
# Epoch 112: err = nan: Win count = 32 Win ratio = 28.31858407079646
# Epoch 113: err = nan: Win count = 33 Win ratio = 28.947368421052634
# Epoch 114: err = nan: Win count = 34 Win ratio = 29.565217391304348
# Epoch 115: err = nan: Win count = 35 Win ratio = 30.17241379310345
# Epoch 116: err = nan: Win count = 35 Win ratio = 29.914529914529915
# Epoch 117: err = nan: Win count = 35 Win ratio = 29.66101694915254
# Epoch 118: err = nan: Win count = 35 Win ratio = 29.411764705882355
# Epoch 119: err = nan: Win count = 35 Win ratio = 29.166666666666668
# Epoch 120: err = nan: Win count = 35 Win ratio = 28.92561983471074
# Epoch 121: err = nan: Win count = 35 Win ratio = 28.688524590163933
# Epoch 122: err = nan: Win count = 35 Win ratio = 28.455284552845526
# Epoch 123: err = nan: Win count = 35 Win ratio = 28.225806451612907
# Epoch 124: err = nan: Win count = 36 Win ratio = 28.799999999999997
# Epoch 125: err = nan: Win count = 36 Win ratio = 28.57142857142857
# Epoch 126: err = nan: Win count = 36 Win ratio = 28.346456692913385
# Epoch 127: err = nan: Win count = 36 Win ratio = 28.125
# Epoch 128: err = nan: Win count = 36 Win ratio = 27.906976744186046
# Epoch 129: err = nan: Win count = 37 Win ratio = 28.46153846153846
# Epoch 130: err = nan: Win count = 37 Win ratio = 28.24427480916031
# Epoch 131: err = nan: Win count = 38 Win ratio = 28.78787878787879
# Epoch 132: err = nan: Win count = 39 Win ratio = 29.32330827067669
# Epoch 133: err = nan: Win count = 39 Win ratio = 29.1044776119403
# Epoch 134: err = nan: Win count = 39 Win ratio = 28.888888888888886
# Epoch 135: err = nan: Win count = 40 Win ratio = 29.411764705882355
# Epoch 136: err = nan: Win count = 40 Win ratio = 29.1970802919708
# Epoch 137: err = nan: Win count = 40 Win ratio = 28.985507246376812
# Epoch 138: err = nan: Win count = 40 Win ratio = 28.776978417266186
# Epoch 139: err = nan: Win count = 40 Win ratio = 28.57142857142857
# Epoch 140: err = nan: Win count = 40 Win ratio = 28.368794326241137
# Epoch 141: err = nan: Win count = 41 Win ratio = 28.87323943661972
# Epoch 142: err = nan: Win count = 41 Win ratio = 28.671328671328673
# Epoch 143: err = nan: Win count = 41 Win ratio = 28.47222222222222
# Epoch 144: err = nan: Win count = 41 Win ratio = 28.27586206896552
# Epoch 145: err = nan: Win count = 41 Win ratio = 28.08219178082192
# Epoch 146: err = nan: Win count = 41 Win ratio = 27.89115646258503
# Epoch 147: err = nan: Win count = 41 Win ratio = 27.7027027027027
# Epoch 148: err = nan: Win count = 41 Win ratio = 27.516778523489933
# Epoch 149: err = nan: Win count = 42 Win ratio = 28.000000000000004
# Epoch 150: err = nan: Win count = 42 Win ratio = 27.81456953642384
# Epoch 151: err = nan: Win count = 42 Win ratio = 27.631578947368425
# Epoch 152: err = nan: Win count = 43 Win ratio = 28.104575163398692
# Epoch 153: err = nan: Win count = 43 Win ratio = 27.92207792207792
# Epoch 154: err = nan: Win count = 44 Win ratio = 28.387096774193548
# Epoch 155: err = nan: Win count = 45 Win ratio = 28.846153846153843
# Epoch 156: err = nan: Win count = 45 Win ratio = 28.662420382165603
# Epoch 157: err = nan: Win count = 46 Win ratio = 29.11392405063291
# Epoch 158: err = nan: Win count = 46 Win ratio = 28.930817610062892
# Epoch 159: err = nan: Win count = 47 Win ratio = 29.375
# Epoch 160: err = nan: Win count = 47 Win ratio = 29.19254658385093
# Epoch 161: err = nan: Win count = 48 Win ratio = 29.629629629629626
# Epoch 162: err = nan: Win count = 49 Win ratio = 30.061349693251532
# Epoch 163: err = nan: Win count = 49 Win ratio = 29.878048780487802
# Epoch 164: err = nan: Win count = 49 Win ratio = 29.6969696969697
# Epoch 165: err = nan: Win count = 50 Win ratio = 30.120481927710845
# Epoch 166: err = nan: Win count = 50 Win ratio = 29.94011976047904
# Epoch 167: err = nan: Win count = 51 Win ratio = 30.357142857142854
# Epoch 168: err = nan: Win count = 51 Win ratio = 30.17751479289941
# Epoch 169: err = nan: Win count = 51 Win ratio = 30.0
# Epoch 170: err = nan: Win count = 51 Win ratio = 29.82456140350877
# Epoch 171: err = nan: Win count = 51 Win ratio = 29.651162790697676
# Epoch 172: err = nan: Win count = 51 Win ratio = 29.47976878612717
# Epoch 173: err = nan: Win count = 51 Win ratio = 29.310344827586203
# Epoch 174: err = nan: Win count = 52 Win ratio = 29.714285714285715
# Epoch 175: err = nan: Win count = 52 Win ratio = 29.545454545454547
# Epoch 176: err = nan: Win count = 52 Win ratio = 29.37853107344633
# Epoch 177: err = nan: Win count = 53 Win ratio = 29.775280898876407
# Epoch 178: err = nan: Win count = 53 Win ratio = 29.608938547486037
# Epoch 179: err = nan: Win count = 53 Win ratio = 29.444444444444446
# Epoch 180: err = nan: Win count = 53 Win ratio = 29.2817679558011
# Epoch 181: err = nan: Win count = 54 Win ratio = 29.67032967032967
# Epoch 182: err = nan: Win count = 55 Win ratio = 30.05464480874317
# Epoch 183: err = nan: Win count = 55 Win ratio = 29.891304347826086
# Epoch 184: err = nan: Win count = 55 Win ratio = 29.72972972972973
# Epoch 185: err = nan: Win count = 55 Win ratio = 29.56989247311828
# Epoch 186: err = nan: Win count = 55 Win ratio = 29.411764705882355
# Epoch 187: err = nan: Win count = 56 Win ratio = 29.78723404255319
# Epoch 188: err = nan: Win count = 56 Win ratio = 29.629629629629626
# Epoch 189: err = nan: Win count = 57 Win ratio = 30.0
# Epoch 190: err = nan: Win count = 57 Win ratio = 29.84293193717277
# Epoch 191: err = nan: Win count = 58 Win ratio = 30.208333333333332
# Epoch 192: err = nan: Win count = 58 Win ratio = 30.05181347150259
# Epoch 193: err = nan: Win count = 58 Win ratio = 29.896907216494846
# Epoch 194: err = nan: Win count = 58 Win ratio = 29.743589743589745
# Epoch 195: err = nan: Win count = 58 Win ratio = 29.591836734693878
# Epoch 196: err = nan: Win count = 58 Win ratio = 29.441624365482234
# Epoch 197: err = nan: Win count = 59 Win ratio = 29.797979797979796
# Epoch 198: err = nan: Win count = 60 Win ratio = 30.15075376884422
# Epoch 199: err = nan: Win count = 60 Win ratio = 30.0
# Epoch 200: err = nan: Win count = 60 Win ratio = 29.850746268656714
# Epoch 201: err = nan: Win count = 60 Win ratio = 29.7029702970297
# Epoch 202: err = nan: Win count = 61 Win ratio = 30.049261083743843
# Epoch 203: err = nan: Win count = 61 Win ratio = 29.901960784313726
# Epoch 204: err = nan: Win count = 61 Win ratio = 29.756097560975608
# Epoch 205: err = nan: Win count = 62 Win ratio = 30.097087378640776
# Epoch 206: err = nan: Win count = 62 Win ratio = 29.951690821256037
# Epoch 207: err = nan: Win count = 62 Win ratio = 29.807692307692307
# Epoch 208: err = nan: Win count = 62 Win ratio = 29.665071770334926
# Epoch 209: err = nan: Win count = 63 Win ratio = 30.0
# Epoch 210: err = nan: Win count = 64 Win ratio = 30.33175355450237
# Epoch 211: err = nan: Win count = 64 Win ratio = 30.18867924528302
# Epoch 212: err = nan: Win count = 64 Win ratio = 30.046948356807512
# Epoch 213: err = nan: Win count = 64 Win ratio = 29.906542056074763
# Epoch 214: err = nan: Win count = 64 Win ratio = 29.767441860465116
# Epoch 215: err = nan: Win count = 65 Win ratio = 30.09259259259259
# Epoch 216: err = nan: Win count = 65 Win ratio = 29.953917050691242
# Epoch 217: err = nan: Win count = 65 Win ratio = 29.81651376146789
# Epoch 218: err = nan: Win count = 65 Win ratio = 29.68036529680365
# Epoch 219: err = nan: Win count = 66 Win ratio = 30.0
# Epoch 220: err = nan: Win count = 66 Win ratio = 29.86425339366516
# Epoch 221: err = nan: Win count = 66 Win ratio = 29.72972972972973
# Epoch 222: err = nan: Win count = 66 Win ratio = 29.596412556053814
# Epoch 223: err = nan: Win count = 67 Win ratio = 29.910714285714285
# Epoch 224: err = nan: Win count = 67 Win ratio = 29.777777777777775
# Epoch 225: err = nan: Win count = 67 Win ratio = 29.646017699115045
# Epoch 226: err = nan: Win count = 68 Win ratio = 29.955947136563875
# Epoch 227: err = nan: Win count = 68 Win ratio = 29.82456140350877
# Epoch 228: err = nan: Win count = 68 Win ratio = 29.694323144104807
# Epoch 229: err = nan: Win count = 68 Win ratio = 29.565217391304348
# Epoch 230: err = nan: Win count = 68 Win ratio = 29.43722943722944
# Epoch 231: err = nan: Win count = 69 Win ratio = 29.74137931034483
# Epoch 232: err = nan: Win count = 69 Win ratio = 29.613733905579398
# Epoch 233: err = nan: Win count = 69 Win ratio = 29.48717948717949
# Epoch 234: err = nan: Win count = 69 Win ratio = 29.361702127659573
# Epoch 235: err = nan: Win count = 70 Win ratio = 29.66101694915254
# Epoch 236: err = nan: Win count = 70 Win ratio = 29.535864978902953
# Epoch 237: err = nan: Win count = 70 Win ratio = 29.411764705882355
# Epoch 238: err = nan: Win count = 71 Win ratio = 29.707112970711297
# Epoch 239: err = nan: Win count = 72 Win ratio = 30.0
# Epoch 240: err = nan: Win count = 72 Win ratio = 29.87551867219917
# Epoch 241: err = nan: Win count = 72 Win ratio = 29.75206611570248
# Epoch 242: err = nan: Win count = 72 Win ratio = 29.629629629629626
# Epoch 243: err = nan: Win count = 72 Win ratio = 29.508196721311474
# Epoch 244: err = nan: Win count = 72 Win ratio = 29.38775510204082
# Epoch 245: err = nan: Win count = 73 Win ratio = 29.67479674796748
# Epoch 246: err = nan: Win count = 73 Win ratio = 29.554655870445345
# Epoch 247: err = nan: Win count = 74 Win ratio = 29.838709677419356
# Epoch 248: err = nan: Win count = 75 Win ratio = 30.120481927710845
# Epoch 249: err = nan: Win count = 75 Win ratio = 30.0
# Epoch 250: err = nan: Win count = 75 Win ratio = 29.880478087649404
# Epoch 251: err = nan: Win count = 75 Win ratio = 29.761904761904763
# Epoch 252: err = nan: Win count = 75 Win ratio = 29.64426877470356
# Epoch 253: err = nan: Win count = 75 Win ratio = 29.527559055118108
# Epoch 254: err = nan: Win count = 75 Win ratio = 29.411764705882355
# Epoch 255: err = nan: Win count = 75 Win ratio = 29.296875
# Epoch 256: err = nan: Win count = 75 Win ratio = 29.18287937743191
# Epoch 257: err = nan: Win count = 76 Win ratio = 29.457364341085274
# Epoch 258: err = nan: Win count = 76 Win ratio = 29.343629343629345
# Epoch 259: err = nan: Win count = 76 Win ratio = 29.230769230769234
# Epoch 260: err = nan: Win count = 76 Win ratio = 29.118773946360154
# Epoch 261: err = nan: Win count = 76 Win ratio = 29.00763358778626
# Epoch 262: err = nan: Win count = 77 Win ratio = 29.277566539923956
# Epoch 263: err = nan: Win count = 77 Win ratio = 29.166666666666668
# Epoch 264: err = nan: Win count = 78 Win ratio = 29.433962264150942
# Epoch 265: err = nan: Win count = 78 Win ratio = 29.32330827067669
# Epoch 266: err = nan: Win count = 78 Win ratio = 29.213483146067414
# Epoch 267: err = nan: Win count = 78 Win ratio = 29.1044776119403
# Epoch 268: err = nan: Win count = 78 Win ratio = 28.99628252788104
# Epoch 269: err = nan: Win count = 78 Win ratio = 28.888888888888886
# Epoch 270: err = nan: Win count = 78 Win ratio = 28.782287822878228
# Epoch 271: err = nan: Win count = 78 Win ratio = 28.676470588235293
# Epoch 272: err = nan: Win count = 78 Win ratio = 28.57142857142857
# Epoch 273: err = nan: Win count = 78 Win ratio = 28.467153284671532
# Epoch 274: err = nan: Win count = 78 Win ratio = 28.363636363636363
# Epoch 275: err = nan: Win count = 78 Win ratio = 28.26086956521739
# Epoch 276: err = nan: Win count = 79 Win ratio = 28.51985559566787
# Epoch 277: err = nan: Win count = 79 Win ratio = 28.41726618705036
# Epoch 278: err = nan: Win count = 79 Win ratio = 28.31541218637993
# Epoch 279: err = nan: Win count = 79 Win ratio = 28.214285714285715
# Epoch 280: err = nan: Win count = 79 Win ratio = 28.11387900355872
# Epoch 281: err = nan: Win count = 79 Win ratio = 28.01418439716312
# Epoch 282: err = nan: Win count = 80 Win ratio = 28.26855123674912
# Epoch 283: err = nan: Win count = 80 Win ratio = 28.169014084507044
# Epoch 284: err = nan: Win count = 80 Win ratio = 28.07017543859649
# Epoch 285: err = nan: Win count = 80 Win ratio = 27.972027972027973
# Epoch 286: err = nan: Win count = 80 Win ratio = 27.874564459930312
# Epoch 287: err = nan: Win count = 81 Win ratio = 28.125
# Epoch 288: err = nan: Win count = 81 Win ratio = 28.027681660899656
# Epoch 289: err = nan: Win count = 81 Win ratio = 27.93103448275862
# Epoch 290: err = nan: Win count = 81 Win ratio = 27.835051546391753
# Epoch 291: err = nan: Win count = 81 Win ratio = 27.73972602739726
# Epoch 292: err = nan: Win count = 81 Win ratio = 27.64505119453925
# Epoch 293: err = nan: Win count = 81 Win ratio = 27.55102040816326
# Epoch 294: err = nan: Win count = 82 Win ratio = 27.796610169491526
# Epoch 295: err = nan: Win count = 83 Win ratio = 28.040540540540544
# Epoch 296: err = nan: Win count = 84 Win ratio = 28.28282828282828
# Epoch 297: err = nan: Win count = 85 Win ratio = 28.523489932885905
# Epoch 298: err = nan: Win count = 85 Win ratio = 28.428093645484946
# Epoch 299: err = nan: Win count = 85 Win ratio = 28.333333333333332
# Epoch 300: err = nan: Win count = 85 Win ratio = 28.23920265780731
# Epoch 301: err = nan: Win count = 85 Win ratio = 28.14569536423841
# Epoch 302: err = nan: Win count = 85 Win ratio = 28.052805280528055
# Epoch 303: err = nan: Win count = 85 Win ratio = 27.960526315789476
# Epoch 304: err = nan: Win count = 85 Win ratio = 27.86885245901639
# Epoch 305: err = nan: Win count = 85 Win ratio = 27.77777777777778
# Epoch 306: err = nan: Win count = 86 Win ratio = 28.013029315960914
# Epoch 307: err = nan: Win count = 87 Win ratio = 28.246753246753247
# Epoch 308: err = nan: Win count = 88 Win ratio = 28.478964401294498
# Epoch 309: err = nan: Win count = 89 Win ratio = 28.70967741935484
# Epoch 310: err = nan: Win count = 89 Win ratio = 28.617363344051448
# Epoch 311: err = nan: Win count = 90 Win ratio = 28.846153846153843
# Epoch 312: err = nan: Win count = 90 Win ratio = 28.753993610223645
# Epoch 313: err = nan: Win count = 90 Win ratio = 28.662420382165603
# Epoch 314: err = nan: Win count = 90 Win ratio = 28.57142857142857
# Epoch 315: err = nan: Win count = 91 Win ratio = 28.79746835443038
# Epoch 316: err = nan: Win count = 92 Win ratio = 29.02208201892745
# Epoch 317: err = nan: Win count = 93 Win ratio = 29.245283018867923
# Epoch 318: err = nan: Win count = 93 Win ratio = 29.153605015673982
# Epoch 319: err = nan: Win count = 93 Win ratio = 29.062500000000004
# Epoch 320: err = nan: Win count = 94 Win ratio = 29.283489096573206
# Epoch 321: err = nan: Win count = 94 Win ratio = 29.19254658385093
# Epoch 322: err = nan: Win count = 94 Win ratio = 29.102167182662537
# Epoch 323: err = nan: Win count = 95 Win ratio = 29.32098765432099
# Epoch 324: err = nan: Win count = 95 Win ratio = 29.230769230769234
# Epoch 325: err = nan: Win count = 95 Win ratio = 29.141104294478527
# Epoch 326: err = nan: Win count = 95 Win ratio = 29.051987767584098
# Epoch 327: err = nan: Win count = 96 Win ratio = 29.268292682926827
# Epoch 328: err = nan: Win count = 96 Win ratio = 29.17933130699088
# Epoch 329: err = nan: Win count = 96 Win ratio = 29.09090909090909
# Epoch 330: err = nan: Win count = 96 Win ratio = 29.003021148036257
# Epoch 331: err = nan: Win count = 96 Win ratio = 28.915662650602407
# Epoch 332: err = nan: Win count = 96 Win ratio = 28.82882882882883
# Epoch 333: err = nan: Win count = 96 Win ratio = 28.74251497005988
# Epoch 334: err = nan: Win count = 96 Win ratio = 28.65671641791045
# Epoch 335: err = nan: Win count = 97 Win ratio = 28.869047619047617
# Epoch 336: err = nan: Win count = 97 Win ratio = 28.783382789317507
# Epoch 337: err = nan: Win count = 97 Win ratio = 28.698224852071007
# Epoch 338: err = nan: Win count = 97 Win ratio = 28.613569321533923
# Epoch 339: err = nan: Win count = 97 Win ratio = 28.52941176470588
# Epoch 340: err = nan: Win count = 98 Win ratio = 28.739002932551323
# Epoch 341: err = nan: Win count = 98 Win ratio = 28.654970760233915
# Epoch 342: err = nan: Win count = 98 Win ratio = 28.57142857142857
# Epoch 343: err = nan: Win count = 99 Win ratio = 28.77906976744186
# Epoch 344: err = nan: Win count = 99 Win ratio = 28.695652173913043
# Epoch 345: err = nan: Win count = 99 Win ratio = 28.61271676300578
# Epoch 346: err = nan: Win count = 99 Win ratio = 28.530259365994237
# Epoch 347: err = nan: Win count = 99 Win ratio = 28.448275862068968
# Epoch 348: err = nan: Win count = 99 Win ratio = 28.36676217765043
# Epoch 349: err = nan: Win count = 99 Win ratio = 28.285714285714285
# Epoch 350: err = nan: Win count = 99 Win ratio = 28.205128205128204
# Epoch 351: err = nan: Win count = 100 Win ratio = 28.40909090909091
# Epoch 352: err = nan: Win count = 100 Win ratio = 28.328611898016998
# Epoch 353: err = nan: Win count = 100 Win ratio = 28.24858757062147
# Epoch 354: err = nan: Win count = 100 Win ratio = 28.169014084507044
# Epoch 355: err = nan: Win count = 100 Win ratio = 28.08988764044944
# Epoch 356: err = nan: Win count = 100 Win ratio = 28.011204481792717
# Epoch 357: err = nan: Win count = 100 Win ratio = 27.932960893854748
# Epoch 358: err = nan: Win count = 100 Win ratio = 27.85515320334262
# Epoch 359: err = nan: Win count = 100 Win ratio = 27.77777777777778
# Epoch 360: err = nan: Win count = 100 Win ratio = 27.70083102493075
# Epoch 361: err = nan: Win count = 100 Win ratio = 27.624309392265197
# Epoch 362: err = nan: Win count = 100 Win ratio = 27.548209366391184
# Epoch 363: err = nan: Win count = 101 Win ratio = 27.747252747252748
# Epoch 364: err = nan: Win count = 101 Win ratio = 27.671232876712327
# Epoch 365: err = nan: Win count = 101 Win ratio = 27.595628415300546
# Epoch 366: err = nan: Win count = 101 Win ratio = 27.520435967302454
# Epoch 367: err = nan: Win count = 102 Win ratio = 27.717391304347828
# Epoch 368: err = nan: Win count = 102 Win ratio = 27.64227642276423
# Epoch 369: err = nan: Win count = 102 Win ratio = 27.56756756756757
# Epoch 370: err = nan: Win count = 102 Win ratio = 27.49326145552561
# Epoch 371: err = nan: Win count = 102 Win ratio = 27.419354838709676
# Epoch 372: err = nan: Win count = 103 Win ratio = 27.61394101876676
# Epoch 373: err = nan: Win count = 104 Win ratio = 27.807486631016044
# Epoch 374: err = nan: Win count = 104 Win ratio = 27.73333333333333
# Epoch 375: err = nan: Win count = 104 Win ratio = 27.659574468085108
# Epoch 376: err = nan: Win count = 104 Win ratio = 27.586206896551722
# Epoch 377: err = nan: Win count = 105 Win ratio = 27.77777777777778
# Epoch 378: err = nan: Win count = 105 Win ratio = 27.70448548812665
# Epoch 379: err = nan: Win count = 106 Win ratio = 27.89473684210526
# Epoch 380: err = nan: Win count = 106 Win ratio = 27.821522309711288
# Epoch 381: err = nan: Win count = 106 Win ratio = 27.748691099476442
# Epoch 382: err = nan: Win count = 106 Win ratio = 27.676240208877285
# Epoch 383: err = nan: Win count = 107 Win ratio = 27.864583333333332
# Epoch 384: err = nan: Win count = 107 Win ratio = 27.79220779220779
# Epoch 385: err = nan: Win count = 107 Win ratio = 27.72020725388601
# Epoch 386: err = nan: Win count = 108 Win ratio = 27.906976744186046
# Epoch 387: err = nan: Win count = 108 Win ratio = 27.835051546391753
# Epoch 388: err = nan: Win count = 108 Win ratio = 27.76349614395887
# Epoch 389: err = nan: Win count = 108 Win ratio = 27.692307692307693
# Epoch 390: err = nan: Win count = 109 Win ratio = 27.877237851662407
# Epoch 391: err = nan: Win count = 109 Win ratio = 27.806122448979593
# Epoch 392: err = nan: Win count = 109 Win ratio = 27.735368956743002
# Epoch 393: err = nan: Win count = 110 Win ratio = 27.918781725888326
# Epoch 394: err = nan: Win count = 111 Win ratio = 28.10126582278481
# Epoch 395: err = nan: Win count = 111 Win ratio = 28.030303030303028
# Epoch 396: err = nan: Win count = 111 Win ratio = 27.95969773299748
# Epoch 397: err = nan: Win count = 112 Win ratio = 28.14070351758794
# Epoch 398: err = nan: Win count = 112 Win ratio = 28.07017543859649
# Epoch 399: err = nan: Win count = 112 Win ratio = 28.000000000000004
# Epoch 400: err = nan: Win count = 112 Win ratio = 27.93017456359102
# Epoch 401: err = nan: Win count = 112 Win ratio = 27.860696517412936
# Epoch 402: err = nan: Win count = 112 Win ratio = 27.791563275434246
# Epoch 403: err = nan: Win count = 113 Win ratio = 27.970297029702973
# Epoch 404: err = nan: Win count = 113 Win ratio = 27.901234567901234
# Epoch 405: err = nan: Win count = 113 Win ratio = 27.832512315270936
# Epoch 406: err = nan: Win count = 113 Win ratio = 27.764127764127768
# Epoch 407: err = nan: Win count = 113 Win ratio = 27.696078431372552
# Epoch 408: err = nan: Win count = 113 Win ratio = 27.628361858190708
# Epoch 409: err = nan: Win count = 114 Win ratio = 27.80487804878049
# Epoch 410: err = nan: Win count = 114 Win ratio = 27.73722627737226
# Epoch 411: err = nan: Win count = 114 Win ratio = 27.669902912621357
# Epoch 412: err = nan: Win count = 114 Win ratio = 27.602905569007262
# Epoch 413: err = nan: Win count = 115 Win ratio = 27.77777777777778
# Epoch 414: err = nan: Win count = 115 Win ratio = 27.710843373493976
# Epoch 415: err = nan: Win count = 115 Win ratio = 27.64423076923077
# Epoch 416: err = nan: Win count = 115 Win ratio = 27.577937649880095
# Epoch 417: err = nan: Win count = 116 Win ratio = 27.751196172248804
# Epoch 418: err = nan: Win count = 116 Win ratio = 27.684964200477324
# Epoch 419: err = nan: Win count = 116 Win ratio = 27.61904761904762
# Epoch 420: err = nan: Win count = 117 Win ratio = 27.790973871733964
# Epoch 421: err = nan: Win count = 117 Win ratio = 27.72511848341232
# Epoch 422: err = nan: Win count = 117 Win ratio = 27.659574468085108
# Epoch 423: err = nan: Win count = 117 Win ratio = 27.594339622641513
# Epoch 424: err = nan: Win count = 117 Win ratio = 27.52941176470588
# Epoch 425: err = nan: Win count = 117 Win ratio = 27.464788732394368
# Epoch 426: err = nan: Win count = 117 Win ratio = 27.400468384074944
# Epoch 427: err = nan: Win count = 118 Win ratio = 27.570093457943923
# Epoch 428: err = nan: Win count = 119 Win ratio = 27.73892773892774
# Epoch 429: err = nan: Win count = 119 Win ratio = 27.674418604651162
# Epoch 430: err = nan: Win count = 119 Win ratio = 27.610208816705335
# Epoch 431: err = nan: Win count = 119 Win ratio = 27.546296296296298
# Epoch 432: err = nan: Win count = 119 Win ratio = 27.48267898383372
# Epoch 433: err = nan: Win count = 119 Win ratio = 27.419354838709676
# Epoch 434: err = nan: Win count = 119 Win ratio = 27.35632183908046
# Epoch 435: err = nan: Win count = 119 Win ratio = 27.293577981651374
# Epoch 436: err = nan: Win count = 119 Win ratio = 27.23112128146453
# Epoch 437: err = nan: Win count = 119 Win ratio = 27.168949771689498
# Epoch 438: err = nan: Win count = 119 Win ratio = 27.10706150341686
# Epoch 439: err = nan: Win count = 120 Win ratio = 27.27272727272727
# Epoch 440: err = nan: Win count = 120 Win ratio = 27.2108843537415
# Epoch 441: err = nan: Win count = 120 Win ratio = 27.149321266968325
# Epoch 442: err = nan: Win count = 120 Win ratio = 27.088036117381492
# Epoch 443: err = nan: Win count = 120 Win ratio = 27.027027027027028
# Epoch 444: err = nan: Win count = 121 Win ratio = 27.191011235955052
# Epoch 445: err = nan: Win count = 122 Win ratio = 27.3542600896861
# Epoch 446: err = nan: Win count = 122 Win ratio = 27.293064876957494
# Epoch 447: err = nan: Win count = 123 Win ratio = 27.455357142857146
# Epoch 448: err = nan: Win count = 123 Win ratio = 27.39420935412027
# Epoch 449: err = nan: Win count = 123 Win ratio = 27.333333333333332
# Epoch 450: err = nan: Win count = 123 Win ratio = 27.27272727272727
# Epoch 451: err = nan: Win count = 123 Win ratio = 27.212389380530972
# Epoch 452: err = nan: Win count = 123 Win ratio = 27.1523178807947
# Epoch 453: err = nan: Win count = 123 Win ratio = 27.09251101321586
# Epoch 454: err = nan: Win count = 123 Win ratio = 27.032967032967033
# Epoch 455: err = nan: Win count = 124 Win ratio = 27.192982456140353
# Epoch 456: err = nan: Win count = 124 Win ratio = 27.13347921225383
# Epoch 457: err = nan: Win count = 124 Win ratio = 27.074235807860266
# Epoch 458: err = nan: Win count = 124 Win ratio = 27.01525054466231
# Epoch 459: err = nan: Win count = 124 Win ratio = 26.956521739130434
# Epoch 460: err = nan: Win count = 124 Win ratio = 26.89804772234273
# Epoch 461: err = nan: Win count = 124 Win ratio = 26.83982683982684
# Epoch 462: err = nan: Win count = 125 Win ratio = 26.997840172786177
# Epoch 463: err = nan: Win count = 125 Win ratio = 26.939655172413797
# Epoch 464: err = nan: Win count = 126 Win ratio = 27.09677419354839
# Epoch 465: err = nan: Win count = 126 Win ratio = 27.038626609442062
# Epoch 466: err = nan: Win count = 126 Win ratio = 26.98072805139186
# Epoch 467: err = nan: Win count = 126 Win ratio = 26.923076923076923
# Epoch 468: err = nan: Win count = 126 Win ratio = 26.865671641791046
# Epoch 469: err = nan: Win count = 126 Win ratio = 26.80851063829787
# Epoch 470: err = nan: Win count = 126 Win ratio = 26.751592356687897
# Epoch 471: err = nan: Win count = 127 Win ratio = 26.906779661016948
# Epoch 472: err = nan: Win count = 127 Win ratio = 26.849894291754755
# Epoch 473: err = nan: Win count = 127 Win ratio = 26.79324894514768
# Epoch 474: err = nan: Win count = 127 Win ratio = 26.736842105263158
# Epoch 475: err = nan: Win count = 127 Win ratio = 26.680672268907564
# Epoch 476: err = nan: Win count = 128 Win ratio = 26.834381551362686
# Epoch 477: err = nan: Win count = 129 Win ratio = 26.98744769874477
# Epoch 478: err = nan: Win count = 130 Win ratio = 27.139874739039666
# Epoch 479: err = nan: Win count = 130 Win ratio = 27.083333333333332
# Epoch 480: err = nan: Win count = 130 Win ratio = 27.027027027027028
# Epoch 481: err = nan: Win count = 130 Win ratio = 26.970954356846473
# Epoch 482: err = nan: Win count = 130 Win ratio = 26.91511387163561
# Epoch 483: err = nan: Win count = 131 Win ratio = 27.066115702479337
# Epoch 484: err = nan: Win count = 131 Win ratio = 27.010309278350515
# Epoch 485: err = nan: Win count = 131 Win ratio = 26.954732510288064
# Epoch 486: err = nan: Win count = 131 Win ratio = 26.899383983572893
# Epoch 487: err = nan: Win count = 131 Win ratio = 26.84426229508197
# Epoch 488: err = nan: Win count = 131 Win ratio = 26.789366053169733
# Epoch 489: err = nan: Win count = 132 Win ratio = 26.93877551020408
# Epoch 490: err = nan: Win count = 132 Win ratio = 26.883910386965375
# Epoch 491: err = nan: Win count = 133 Win ratio = 27.03252032520325
# Epoch 492: err = nan: Win count = 133 Win ratio = 26.97768762677485
# Epoch 493: err = nan: Win count = 134 Win ratio = 27.125506072874494
# Epoch 494: err = nan: Win count = 134 Win ratio = 27.070707070707073
# Epoch 495: err = nan: Win count = 135 Win ratio = 27.21774193548387
# Epoch 496: err = nan: Win count = 135 Win ratio = 27.16297786720322
# Epoch 497: err = nan: Win count = 135 Win ratio = 27.10843373493976
# Epoch 498: err = nan: Win count = 135 Win ratio = 27.054108216432866
# Epoch 499: err = nan: Win count = 135 Win ratio = 27.0
# Epoch 500: err = nan: Win count = 136 Win ratio = 27.14570858283433
# Epoch 501: err = nan: Win count = 136 Win ratio = 27.091633466135455
# Epoch 502: err = nan: Win count = 136 Win ratio = 27.037773359840955
# Epoch 503: err = nan: Win count = 137 Win ratio = 27.18253968253968
# Epoch 504: err = nan: Win count = 137 Win ratio = 27.12871287128713
# Epoch 505: err = nan: Win count = 137 Win ratio = 27.07509881422925
# Epoch 506: err = nan: Win count = 137 Win ratio = 27.021696252465482
# Epoch 507: err = nan: Win count = 137 Win ratio = 26.968503937007878
# Epoch 508: err = nan: Win count = 137 Win ratio = 26.91552062868369
# Epoch 509: err = nan: Win count = 137 Win ratio = 26.862745098039216
# Epoch 510: err = nan: Win count = 138 Win ratio = 27.00587084148728
# Epoch 511: err = nan: Win count = 138 Win ratio = 26.953125
# Epoch 512: err = nan: Win count = 139 Win ratio = 27.09551656920078
# Epoch 513: err = nan: Win count = 140 Win ratio = 27.237354085603112
# Epoch 514: err = nan: Win count = 140 Win ratio = 27.184466019417474
# Epoch 515: err = nan: Win count = 140 Win ratio = 27.131782945736433
# Epoch 516: err = nan: Win count = 140 Win ratio = 27.079303675048354
# Epoch 517: err = nan: Win count = 140 Win ratio = 27.027027027027028
# Epoch 518: err = nan: Win count = 140 Win ratio = 26.97495183044316
# Epoch 519: err = nan: Win count = 141 Win ratio = 27.115384615384613
# Epoch 520: err = nan: Win count = 142 Win ratio = 27.2552783109405
# Epoch 521: err = nan: Win count = 142 Win ratio = 27.203065134099617
# Epoch 522: err = nan: Win count = 143 Win ratio = 27.342256214149142
# Epoch 523: err = nan: Win count = 143 Win ratio = 27.29007633587786
# Epoch 524: err = nan: Win count = 143 Win ratio = 27.23809523809524
# Epoch 525: err = nan: Win count = 143 Win ratio = 27.186311787072242
# Epoch 526: err = nan: Win count = 143 Win ratio = 27.13472485768501
# Epoch 527: err = nan: Win count = 143 Win ratio = 27.083333333333332
# Epoch 528: err = nan: Win count = 143 Win ratio = 27.032136105860115
# Epoch 529: err = nan: Win count = 143 Win ratio = 26.9811320754717
# Epoch 530: err = nan: Win count = 144 Win ratio = 27.11864406779661
# Epoch 531: err = nan: Win count = 145 Win ratio = 27.25563909774436
# Epoch 532: err = nan: Win count = 145 Win ratio = 27.204502814258912
# Epoch 533: err = nan: Win count = 145 Win ratio = 27.153558052434455
# Epoch 534: err = nan: Win count = 146 Win ratio = 27.289719626168225
# Epoch 535: err = nan: Win count = 146 Win ratio = 27.238805970149254
# Epoch 536: err = nan: Win count = 147 Win ratio = 27.37430167597765
# Epoch 537: err = nan: Win count = 147 Win ratio = 27.323420074349443
# Epoch 538: err = nan: Win count = 147 Win ratio = 27.27272727272727
# Epoch 539: err = nan: Win count = 147 Win ratio = 27.22222222222222
# Epoch 540: err = nan: Win count = 147 Win ratio = 27.171903881700555
# Epoch 541: err = nan: Win count = 147 Win ratio = 27.121771217712176
# Epoch 542: err = nan: Win count = 147 Win ratio = 27.071823204419886
# Epoch 543: err = nan: Win count = 148 Win ratio = 27.205882352941174
# Epoch 544: err = nan: Win count = 148 Win ratio = 27.155963302752294
# Epoch 545: err = nan: Win count = 149 Win ratio = 27.28937728937729
# Epoch 546: err = nan: Win count = 149 Win ratio = 27.239488117001827
# Epoch 547: err = nan: Win count = 149 Win ratio = 27.189781021897808
# Epoch 548: err = nan: Win count = 149 Win ratio = 27.140255009107467
# Epoch 549: err = nan: Win count = 149 Win ratio = 27.090909090909093
# Epoch 550: err = nan: Win count = 149 Win ratio = 27.041742286751365
# Epoch 551: err = nan: Win count = 150 Win ratio = 27.173913043478258
# Epoch 552: err = nan: Win count = 150 Win ratio = 27.124773960217
# Epoch 553: err = nan: Win count = 150 Win ratio = 27.075812274368232
# Epoch 554: err = nan: Win count = 150 Win ratio = 27.027027027027028
# Epoch 555: err = nan: Win count = 150 Win ratio = 26.978417266187048
# Epoch 556: err = nan: Win count = 150 Win ratio = 26.929982046678635
# Epoch 557: err = nan: Win count = 150 Win ratio = 26.881720430107524
# Epoch 558: err = nan: Win count = 150 Win ratio = 26.833631484794275
# Epoch 559: err = nan: Win count = 150 Win ratio = 26.785714285714285
# Epoch 560: err = nan: Win count = 150 Win ratio = 26.737967914438503
# Epoch 561: err = nan: Win count = 150 Win ratio = 26.690391459074732
# Epoch 562: err = nan: Win count = 151 Win ratio = 26.820603907637658
# Epoch 563: err = nan: Win count = 152 Win ratio = 26.95035460992908
# Epoch 564: err = nan: Win count = 152 Win ratio = 26.902654867256636
# Epoch 565: err = nan: Win count = 152 Win ratio = 26.855123674911663
# Epoch 566: err = nan: Win count = 152 Win ratio = 26.807760141093475
# Epoch 567: err = nan: Win count = 153 Win ratio = 26.936619718309856
# Epoch 568: err = nan: Win count = 153 Win ratio = 26.889279437609844
# Epoch 569: err = nan: Win count = 154 Win ratio = 27.017543859649123
# Epoch 570: err = nan: Win count = 154 Win ratio = 26.970227670753065
# Epoch 571: err = nan: Win count = 155 Win ratio = 27.0979020979021
# Epoch 572: err = nan: Win count = 155 Win ratio = 27.05061082024433
# Epoch 573: err = nan: Win count = 155 Win ratio = 27.00348432055749
# Epoch 574: err = nan: Win count = 155 Win ratio = 26.956521739130434
# Epoch 575: err = nan: Win count = 155 Win ratio = 26.90972222222222
# Epoch 576: err = nan: Win count = 155 Win ratio = 26.8630849220104
# Epoch 577: err = nan: Win count = 155 Win ratio = 26.81660899653979
# Epoch 578: err = nan: Win count = 156 Win ratio = 26.94300518134715
# Epoch 579: err = nan: Win count = 156 Win ratio = 26.89655172413793
# Epoch 580: err = nan: Win count = 156 Win ratio = 26.850258175559382
# Epoch 581: err = nan: Win count = 156 Win ratio = 26.804123711340207
# Epoch 582: err = nan: Win count = 157 Win ratio = 26.929674099485418
# Epoch 583: err = nan: Win count = 157 Win ratio = 26.88356164383562
# Epoch 584: err = nan: Win count = 157 Win ratio = 26.837606837606838
# Epoch 585: err = nan: Win count = 157 Win ratio = 26.791808873720136
# Epoch 586: err = nan: Win count = 157 Win ratio = 26.74616695059625
# Epoch 587: err = nan: Win count = 157 Win ratio = 26.700680272108844
# Epoch 588: err = nan: Win count = 157 Win ratio = 26.6553480475382
# Epoch 589: err = nan: Win count = 157 Win ratio = 26.610169491525426
# Epoch 590: err = nan: Win count = 158 Win ratio = 26.73434856175973
# Epoch 591: err = nan: Win count = 159 Win ratio = 26.85810810810811
# Epoch 592: err = nan: Win count = 159 Win ratio = 26.812816188870155
# Epoch 593: err = nan: Win count = 159 Win ratio = 26.767676767676768
# Epoch 594: err = nan: Win count = 159 Win ratio = 26.722689075630253
# Epoch 595: err = nan: Win count = 159 Win ratio = 26.677852348993287
# Epoch 596: err = nan: Win count = 160 Win ratio = 26.800670016750416
# Epoch 597: err = nan: Win count = 160 Win ratio = 26.755852842809364
# Epoch 598: err = nan: Win count = 161 Win ratio = 26.878130217028378
# Epoch 599: err = nan: Win count = 161 Win ratio = 26.833333333333332
# Epoch 600: err = nan: Win count = 161 Win ratio = 26.788685524126453
# Epoch 601: err = nan: Win count = 161 Win ratio = 26.744186046511626
# Epoch 602: err = nan: Win count = 161 Win ratio = 26.69983416252073
# Epoch 603: err = nan: Win count = 162 Win ratio = 26.82119205298013
# Epoch 604: err = nan: Win count = 163 Win ratio = 26.942148760330582
# Epoch 605: err = nan: Win count = 163 Win ratio = 26.897689768976896
# Epoch 606: err = nan: Win count = 163 Win ratio = 26.85337726523888
# Epoch 607: err = nan: Win count = 163 Win ratio = 26.80921052631579
# Epoch 608: err = nan: Win count = 163 Win ratio = 26.76518883415435
# Epoch 609: err = nan: Win count = 164 Win ratio = 26.885245901639344
# Epoch 610: err = nan: Win count = 164 Win ratio = 26.841243862520457
# Epoch 611: err = nan: Win count = 164 Win ratio = 26.797385620915033
# Epoch 612: err = nan: Win count = 164 Win ratio = 26.753670473083197
# Epoch 613: err = nan: Win count = 164 Win ratio = 26.710097719869708
# Epoch 614: err = nan: Win count = 164 Win ratio = 26.666666666666668
# Epoch 615: err = nan: Win count = 164 Win ratio = 26.623376623376622
# Epoch 616: err = nan: Win count = 164 Win ratio = 26.580226904376016
# Epoch 617: err = nan: Win count = 164 Win ratio = 26.537216828478964
# Epoch 618: err = nan: Win count = 164 Win ratio = 26.494345718901453
# Epoch 619: err = nan: Win count = 165 Win ratio = 26.61290322580645
# Epoch 620: err = nan: Win count = 165 Win ratio = 26.570048309178745
# Epoch 621: err = nan: Win count = 165 Win ratio = 26.527331189710612
# Epoch 622: err = nan: Win count = 165 Win ratio = 26.484751203852326
# Epoch 623: err = nan: Win count = 165 Win ratio = 26.442307692307693
# Epoch 624: err = nan: Win count = 166 Win ratio = 26.56
# Epoch 625: err = nan: Win count = 166 Win ratio = 26.517571884984026
# Epoch 626: err = nan: Win count = 166 Win ratio = 26.475279106858054
# Epoch 627: err = nan: Win count = 166 Win ratio = 26.43312101910828
# Epoch 628: err = nan: Win count = 166 Win ratio = 26.391096979332275
# Epoch 629: err = nan: Win count = 166 Win ratio = 26.34920634920635
# Epoch 630: err = nan: Win count = 166 Win ratio = 26.30744849445325
# Epoch 631: err = nan: Win count = 166 Win ratio = 26.265822784810126
# Epoch 632: err = nan: Win count = 167 Win ratio = 26.38230647709321
# Epoch 633: err = nan: Win count = 168 Win ratio = 26.498422712933756
# Epoch 634: err = nan: Win count = 169 Win ratio = 26.614173228346456
# Epoch 635: err = nan: Win count = 170 Win ratio = 26.729559748427672
# Epoch 636: err = nan: Win count = 170 Win ratio = 26.687598116169546
# Epoch 637: err = nan: Win count = 170 Win ratio = 26.64576802507837
# Epoch 638: err = nan: Win count = 170 Win ratio = 26.604068857589986
# Epoch 639: err = nan: Win count = 170 Win ratio = 26.5625
# Epoch 640: err = nan: Win count = 170 Win ratio = 26.521060842433698
# Epoch 641: err = nan: Win count = 171 Win ratio = 26.635514018691588
# Epoch 642: err = nan: Win count = 172 Win ratio = 26.749611197511662
# Epoch 643: err = nan: Win count = 172 Win ratio = 26.70807453416149
# Epoch 644: err = nan: Win count = 172 Win ratio = 26.666666666666668
# Epoch 645: err = nan: Win count = 172 Win ratio = 26.625386996904027
# Epoch 646: err = nan: Win count = 173 Win ratio = 26.738794435857805
# Epoch 647: err = nan: Win count = 174 Win ratio = 26.851851851851855
# Epoch 648: err = nan: Win count = 174 Win ratio = 26.810477657935284
# Epoch 649: err = nan: Win count = 175 Win ratio = 26.923076923076923
# Epoch 650: err = nan: Win count = 176 Win ratio = 27.035330261136714
# Epoch 651: err = nan: Win count = 176 Win ratio = 26.993865030674847
# Epoch 652: err = nan: Win count = 177 Win ratio = 27.105666156202147
# Epoch 653: err = nan: Win count = 177 Win ratio = 27.06422018348624
# Epoch 654: err = nan: Win count = 177 Win ratio = 27.022900763358777
# Epoch 655: err = nan: Win count = 177 Win ratio = 26.981707317073173
# Epoch 656: err = nan: Win count = 177 Win ratio = 26.94063926940639
# Epoch 657: err = nan: Win count = 178 Win ratio = 27.0516717325228
# Epoch 658: err = nan: Win count = 178 Win ratio = 27.010622154779966
# Epoch 659: err = nan: Win count = 179 Win ratio = 27.121212121212125
# Epoch 660: err = nan: Win count = 179 Win ratio = 27.08018154311649
# Epoch 661: err = nan: Win count = 180 Win ratio = 27.19033232628399
# Epoch 662: err = nan: Win count = 181 Win ratio = 27.300150829562593
# Epoch 663: err = nan: Win count = 181 Win ratio = 27.259036144578314
# Epoch 664: err = nan: Win count = 181 Win ratio = 27.21804511278195
# Epoch 665: err = nan: Win count = 181 Win ratio = 27.177177177177175
# Epoch 666: err = nan: Win count = 181 Win ratio = 27.136431784107945
# Epoch 667: err = nan: Win count = 181 Win ratio = 27.095808383233532
# Epoch 668: err = nan: Win count = 182 Win ratio = 27.204783258594915
# Epoch 669: err = nan: Win count = 182 Win ratio = 27.164179104477608
# Epoch 670: err = nan: Win count = 182 Win ratio = 27.123695976154995
# Epoch 671: err = nan: Win count = 183 Win ratio = 27.232142857142854
# Epoch 672: err = nan: Win count = 184 Win ratio = 27.340267459138186
# Epoch 673: err = nan: Win count = 184 Win ratio = 27.299703264094955
# Epoch 674: err = nan: Win count = 184 Win ratio = 27.25925925925926
# Epoch 675: err = nan: Win count = 184 Win ratio = 27.218934911242602
# Epoch 676: err = nan: Win count = 184 Win ratio = 27.17872968980798
# Epoch 677: err = nan: Win count = 185 Win ratio = 27.286135693215343
# Epoch 678: err = nan: Win count = 186 Win ratio = 27.393225331369663
# Epoch 679: err = nan: Win count = 186 Win ratio = 27.35294117647059
# Epoch 680: err = nan: Win count = 186 Win ratio = 27.312775330396477
# Epoch 681: err = nan: Win count = 187 Win ratio = 27.419354838709676
# Epoch 682: err = nan: Win count = 188 Win ratio = 27.52562225475842
# Epoch 683: err = nan: Win count = 189 Win ratio = 27.631578947368425
# Epoch 684: err = nan: Win count = 189 Win ratio = 27.59124087591241
# Epoch 685: err = nan: Win count = 189 Win ratio = 27.55102040816326
# Epoch 686: err = nan: Win count = 189 Win ratio = 27.510917030567683
# Epoch 687: err = nan: Win count = 189 Win ratio = 27.47093023255814
# Epoch 688: err = nan: Win count = 190 Win ratio = 27.576197387518143
# Epoch 689: err = nan: Win count = 190 Win ratio = 27.536231884057973
# Epoch 690: err = nan: Win count = 191 Win ratio = 27.641099855282196
# Epoch 691: err = nan: Win count = 192 Win ratio = 27.74566473988439
# Epoch 692: err = nan: Win count = 192 Win ratio = 27.705627705627705
# Epoch 693: err = nan: Win count = 193 Win ratio = 27.80979827089337
# Epoch 694: err = nan: Win count = 193 Win ratio = 27.769784172661872
# Epoch 695: err = nan: Win count = 193 Win ratio = 27.729885057471265
# Epoch 696: err = nan: Win count = 194 Win ratio = 27.83357245337159
# Epoch 697: err = nan: Win count = 195 Win ratio = 27.936962750716333
# Epoch 698: err = nan: Win count = 195 Win ratio = 27.896995708154503
# Epoch 699: err = nan: Win count = 195 Win ratio = 27.857142857142858
# Epoch 700: err = nan: Win count = 196 Win ratio = 27.960057061340944
# Epoch 701: err = nan: Win count = 196 Win ratio = 27.92022792022792
# Epoch 702: err = nan: Win count = 197 Win ratio = 28.02275960170697
# Epoch 703: err = nan: Win count = 198 Win ratio = 28.125
# Epoch 704: err = nan: Win count = 198 Win ratio = 28.085106382978726
# Epoch 705: err = nan: Win count = 198 Win ratio = 28.04532577903683
# Epoch 706: err = nan: Win count = 198 Win ratio = 28.005657708628007
# Epoch 707: err = nan: Win count = 198 Win ratio = 27.966101694915253
# Epoch 708: err = nan: Win count = 198 Win ratio = 27.926657263751764
# Epoch 709: err = nan: Win count = 198 Win ratio = 27.887323943661972
# Epoch 710: err = nan: Win count = 198 Win ratio = 27.848101265822784
# Epoch 711: err = nan: Win count = 198 Win ratio = 27.808988764044944
# Epoch 712: err = nan: Win count = 198 Win ratio = 27.769985974754558
# ...
# Epoch 769: err = nan: Win count = 214 Win ratio = 27.79220779220779
# Epoch 770: err = nan: Win count = 215 Win ratio = 27.88586251621271
# Epoch 771: err = nan: Win count = 216 Win ratio = 27.979274611398964
# Epoch 772: err = nan: Win count = 216 Win ratio = 27.943078913324708
# Epoch 773: err = nan: Win count = 216 Win ratio = 27.906976744186046
# Epoch 774: err = nan: Win count = 216 Win ratio = 27.87096774193548
# Epoch 775: err = nan: Win count = 217 Win ratio = 27.963917525773198
# Epoch 776: err = nan: Win count = 217 Win ratio = 27.927927927927925
# Epoch 777: err = nan: Win count = 218 Win ratio = 28.020565552699228
# Epoch 778: err = nan: Win count = 218 Win ratio = 27.984595635430036
# Epoch 779: err = nan: Win count = 218 Win ratio = 27.94871794871795
# Epoch 780: err = nan: Win count = 219 Win ratio = 28.040973111395644
# Epoch 781: err = nan: Win count = 219 Win ratio = 28.005115089514064
# Epoch 782: err = nan: Win count = 219 Win ratio = 27.969348659003828
# Epoch 783: err = nan: Win count = 219 Win ratio = 27.933673469387756
# Epoch 784: err = nan: Win count = 219 Win ratio = 27.898089171974522
# Epoch 785: err = nan: Win count = 219 Win ratio = 27.86259541984733
# Epoch 786: err = nan: Win count = 219 Win ratio = 27.82719186785261
# Epoch 787: err = nan: Win count = 220 Win ratio = 27.918781725888326
# Epoch 788: err = nan: Win count = 221 Win ratio = 28.010139416983527
# Epoch 789: err = nan: Win count = 221 Win ratio = 27.974683544303797
# Epoch 790: err = nan: Win count = 222 Win ratio = 28.06573957016435
# Epoch 791: err = nan: Win count = 223 Win ratio = 28.156565656565657
# Epoch 792: err = nan: Win count = 224 Win ratio = 28.247162673392186
# Epoch 793: err = nan: Win count = 224 Win ratio = 28.211586901763226
# Epoch 794: err = nan: Win count = 224 Win ratio = 28.17610062893082
# Epoch 795: err = nan: Win count = 225 Win ratio = 28.266331658291456
# Epoch 796: err = nan: Win count = 225 Win ratio = 28.23086574654956
# Epoch 797: err = nan: Win count = 225 Win ratio = 28.195488721804512
# Epoch 798: err = nan: Win count = 225 Win ratio = 28.16020025031289
# Epoch 799: err = nan: Win count = 225 Win ratio = 28.125
# Epoch 800: err = nan: Win count = 225 Win ratio = 28.08988764044944
# Epoch 801: err = nan: Win count = 225 Win ratio = 28.05486284289277
# Epoch 802: err = nan: Win count = 225 Win ratio = 28.019925280199253
# Epoch 803: err = nan: Win count = 226 Win ratio = 28.109452736318406
# Epoch 804: err = nan: Win count = 227 Win ratio = 28.19875776397516
# Epoch 805: err = nan: Win count = 227 Win ratio = 28.16377171215881
# Epoch 806: err = nan: Win count = 227 Win ratio = 28.12887236679058
# Epoch 807: err = nan: Win count = 227 Win ratio = 28.094059405940598
# Epoch 808: err = nan: Win count = 227 Win ratio = 28.059332509270707
# Epoch 809: err = nan: Win count = 228 Win ratio = 28.14814814814815
# Epoch 810: err = nan: Win count = 228 Win ratio = 28.113440197287296
# Epoch 811: err = nan: Win count = 228 Win ratio = 28.078817733990146
# Epoch 812: err = nan: Win count = 228 Win ratio = 28.044280442804425
# Epoch 813: err = nan: Win count = 228 Win ratio = 28.00982800982801
# Epoch 814: err = nan: Win count = 228 Win ratio = 27.975460122699385
# Epoch 815: err = nan: Win count = 228 Win ratio = 27.941176470588236
# Epoch 816: err = nan: Win count = 228 Win ratio = 27.906976744186046
# Epoch 817: err = nan: Win count = 228 Win ratio = 27.87286063569682
# Epoch 818: err = nan: Win count = 228 Win ratio = 27.83882783882784
# Epoch 819: err = nan: Win count = 228 Win ratio = 27.80487804878049
# Epoch 820: err = nan: Win count = 228 Win ratio = 27.77101096224117
# Epoch 821: err = nan: Win count = 228 Win ratio = 27.73722627737226
# Epoch 822: err = nan: Win count = 228 Win ratio = 27.703523693803163
# Epoch 823: err = nan: Win count = 228 Win ratio = 27.669902912621357
# Epoch 824: err = nan: Win count = 229 Win ratio = 27.757575757575758
# Epoch 825: err = nan: Win count = 230 Win ratio = 27.845036319612593
# Epoch 826: err = nan: Win count = 230 Win ratio = 27.81136638452237
# Epoch 827: err = nan: Win count = 230 Win ratio = 27.77777777777778
# Epoch 828: err = nan: Win count = 230 Win ratio = 27.744270205066346
# Epoch 829: err = nan: Win count = 230 Win ratio = 27.710843373493976
# Epoch 830: err = nan: Win count = 230 Win ratio = 27.67749699157641
# Epoch 831: err = nan: Win count = 230 Win ratio = 27.64423076923077
# Epoch 832: err = nan: Win count = 230 Win ratio = 27.611044417767104
# Epoch 833: err = nan: Win count = 230 Win ratio = 27.577937649880095
# Epoch 834: err = nan: Win count = 230 Win ratio = 27.54491017964072
# Epoch 835: err = nan: Win count = 230 Win ratio = 27.51196172248804
# Epoch 836: err = nan: Win count = 230 Win ratio = 27.479091995221026
# Epoch 837: err = nan: Win count = 230 Win ratio = 27.44630071599045
# Epoch 838: err = nan: Win count = 230 Win ratio = 27.413587604290825
# Epoch 839: err = nan: Win count = 230 Win ratio = 27.380952380952383
# Epoch 840: err = nan: Win count = 230 Win ratio = 27.348394768133176
# Epoch 841: err = nan: Win count = 230 Win ratio = 27.315914489311165
# Epoch 842: err = nan: Win count = 231 Win ratio = 27.402135231316727
# Epoch 843: err = nan: Win count = 231 Win ratio = 27.3696682464455
# Epoch 844: err = nan: Win count = 231 Win ratio = 27.337278106508876
# Epoch 845: err = nan: Win count = 231 Win ratio = 27.30496453900709
# Epoch 846: err = nan: Win count = 231 Win ratio = 27.27272727272727
# Epoch 847: err = nan: Win count = 231 Win ratio = 27.240566037735846
# Epoch 848: err = nan: Win count = 231 Win ratio = 27.208480565371023
# Epoch 849: err = nan: Win count = 232 Win ratio = 27.294117647058826
# Epoch 850: err = nan: Win count = 232 Win ratio = 27.262044653348998
# Epoch 851: err = nan: Win count = 232 Win ratio = 27.230046948356808
# Epoch 852: err = nan: Win count = 232 Win ratio = 27.198124267291913
# Epoch 853: err = nan: Win count = 233 Win ratio = 27.28337236533958
# Epoch 854: err = nan: Win count = 233 Win ratio = 27.251461988304094
# Epoch 855: err = nan: Win count = 233 Win ratio = 27.2196261682243
# Epoch 856: err = nan: Win count = 233 Win ratio = 27.18786464410735
# Epoch 857: err = nan: Win count = 233 Win ratio = 27.156177156177158
# Epoch 858: err = nan: Win count = 233 Win ratio = 27.124563445867288
# Epoch 859: err = nan: Win count = 233 Win ratio = 27.093023255813954
# Epoch 860: err = nan: Win count = 234 Win ratio = 27.177700348432055
# Epoch 861: err = nan: Win count = 234 Win ratio = 27.1461716937355
# Epoch 862: err = nan: Win count = 235 Win ratio = 27.230590961761298
# Epoch 863: err = nan: Win count = 236 Win ratio = 27.314814814814813
# Epoch 864: err = nan: Win count = 237 Win ratio = 27.398843930635834
# Epoch 865: err = nan: Win count = 237 Win ratio = 27.367205542725177
# Epoch 866: err = nan: Win count = 238 Win ratio = 27.450980392156865
# Epoch 867: err = nan: Win count = 238 Win ratio = 27.419354838709676
# Epoch 868: err = nan: Win count = 238 Win ratio = 27.387802071346375
# Epoch 869: err = nan: Win count = 238 Win ratio = 27.35632183908046
# Epoch 870: err = nan: Win count = 238 Win ratio = 27.324913892078072
# Epoch 871: err = nan: Win count = 238 Win ratio = 27.293577981651374
# Epoch 872: err = nan: Win count = 238 Win ratio = 27.262313860252004
# Epoch 873: err = nan: Win count = 238 Win ratio = 27.23112128146453
# Epoch 874: err = nan: Win count = 238 Win ratio = 27.200000000000003
# Epoch 875: err = nan: Win count = 238 Win ratio = 27.168949771689498
# Epoch 876: err = nan: Win count = 238 Win ratio = 27.137970353477765
# Epoch 877: err = nan: Win count = 238 Win ratio = 27.10706150341686
# Epoch 878: err = nan: Win count = 239 Win ratio = 27.189988623435724
# Epoch 879: err = nan: Win count = 239 Win ratio = 27.15909090909091
# Epoch 880: err = nan: Win count = 239 Win ratio = 27.128263337116916
# Epoch 881: err = nan: Win count = 240 Win ratio = 27.2108843537415
# Epoch 882: err = nan: Win count = 240 Win ratio = 27.18006795016987
# Epoch 883: err = nan: Win count = 241 Win ratio = 27.262443438914026
# Epoch 884: err = nan: Win count = 241 Win ratio = 27.231638418079097
# Epoch 885: err = nan: Win count = 241 Win ratio = 27.200902934537247
# Epoch 886: err = nan: Win count = 241 Win ratio = 27.17023675310034
# Epoch 887: err = nan: Win count = 241 Win ratio = 27.13963963963964
# Epoch 888: err = nan: Win count = 241 Win ratio = 27.10911136107986
# Epoch 889: err = nan: Win count = 241 Win ratio = 27.078651685393258
# Epoch 890: err = nan: Win count = 241 Win ratio = 27.048260381593714
# Epoch 891: err = nan: Win count = 241 Win ratio = 27.017937219730943
# Epoch 892: err = nan: Win count = 241 Win ratio = 26.98768197088466
# Epoch 893: err = nan: Win count = 241 Win ratio = 26.957494407158837
# Epoch 894: err = nan: Win count = 241 Win ratio = 26.927374301675975
# Epoch 895: err = nan: Win count = 241 Win ratio = 26.89732142857143
# Epoch 896: err = nan: Win count = 242 Win ratio = 26.978818283166113
# Epoch 897: err = nan: Win count = 243 Win ratio = 27.060133630289535
# Epoch 898: err = nan: Win count = 243 Win ratio = 27.030033370411566
# Epoch 899: err = nan: Win count = 243 Win ratio = 27.0
# Epoch 900: err = nan: Win count = 244 Win ratio = 27.081021087680355
# Epoch 901: err = nan: Win count = 244 Win ratio = 27.0509977827051
# Epoch 902: err = nan: Win count = 244 Win ratio = 27.02104097452935
# Epoch 903: err = nan: Win count = 244 Win ratio = 26.991150442477874
# Epoch 904: err = nan: Win count = 244 Win ratio = 26.96132596685083
# Epoch 905: err = nan: Win count = 244 Win ratio = 26.93156732891832
# Epoch 906: err = nan: Win count = 244 Win ratio = 26.9018743109151
# Epoch 907: err = nan: Win count = 244 Win ratio = 26.87224669603524
# Epoch 908: err = nan: Win count = 244 Win ratio = 26.842684268426844
# Epoch 909: err = nan: Win count = 244 Win ratio = 26.813186813186814
# Epoch 910: err = nan: Win count = 245 Win ratio = 26.893523600439078
# Epoch 911: err = nan: Win count = 245 Win ratio = 26.864035087719294
# Epoch 912: err = nan: Win count = 246 Win ratio = 26.944140197152244
# Epoch 913: err = nan: Win count = 247 Win ratio = 27.02407002188184
# Epoch 914: err = nan: Win count = 247 Win ratio = 26.994535519125684
# Epoch 915: err = nan: Win count = 247 Win ratio = 26.965065502183407
# Epoch 916: err = nan: Win count = 248 Win ratio = 27.044711014176663
# Epoch 917: err = nan: Win count = 248 Win ratio = 27.01525054466231
# Epoch 918: err = nan: Win count = 249 Win ratio = 27.094668117519046
# Epoch 919: err = nan: Win count = 250 Win ratio = 27.173913043478258
# Epoch 920: err = nan: Win count = 250 Win ratio = 27.14440825190011
# Epoch 921: err = nan: Win count = 250 Win ratio = 27.114967462039047
# Epoch 922: err = nan: Win count = 250 Win ratio = 27.085590465872155
# Epoch 923: err = nan: Win count = 250 Win ratio = 27.056277056277057
# Epoch 924: err = nan: Win count = 250 Win ratio = 27.027027027027028
# Epoch 925: err = nan: Win count = 250 Win ratio = 26.997840172786177
# Epoch 926: err = nan: Win count = 250 Win ratio = 26.968716289104638
# Epoch 927: err = nan: Win count = 250 Win ratio = 26.939655172413797
# Epoch 928: err = nan: Win count = 251 Win ratio = 27.018299246501616
# Epoch 929: err = nan: Win count = 251 Win ratio = 26.989247311827956
# Epoch 930: err = nan: Win count = 252 Win ratio = 27.06766917293233
# Epoch 931: err = nan: Win count = 252 Win ratio = 27.038626609442062
# Epoch 932: err = nan: Win count = 252 Win ratio = 27.009646302250808
# Epoch 933: err = nan: Win count = 252 Win ratio = 26.98072805139186
# Epoch 934: err = nan: Win count = 253 Win ratio = 27.058823529411764
# Epoch 935: err = nan: Win count = 254 Win ratio = 27.136752136752136
# Epoch 936: err = nan: Win count = 255 Win ratio = 27.2145144076841
# Epoch 937: err = nan: Win count = 255 Win ratio = 27.185501066098084
# Epoch 938: err = nan: Win count = 255 Win ratio = 27.15654952076677
# Epoch 939: err = nan: Win count = 255 Win ratio = 27.127659574468083
# Epoch 940: err = nan: Win count = 256 Win ratio = 27.20510095642933
# Epoch 941: err = nan: Win count = 256 Win ratio = 27.176220806794056
# Epoch 942: err = nan: Win count = 256 Win ratio = 27.1474019088017
# Epoch 943: err = nan: Win count = 256 Win ratio = 27.11864406779661
# Epoch 944: err = nan: Win count = 256 Win ratio = 27.089947089947092
# Epoch 945: err = nan: Win count = 257 Win ratio = 27.167019027484145
# Epoch 946: err = nan: Win count = 258 Win ratio = 27.243928194297784
# Epoch 947: err = nan: Win count = 258 Win ratio = 27.21518987341772
# Epoch 948: err = nan: Win count = 258 Win ratio = 27.186512118018967
# Epoch 949: err = nan: Win count = 258 Win ratio = 27.157894736842103
# Epoch 950: err = nan: Win count = 258 Win ratio = 27.129337539432175
# Epoch 951: err = nan: Win count = 258 Win ratio = 27.100840336134453
# Epoch 952: err = nan: Win count = 258 Win ratio = 27.07240293809024
# Epoch 953: err = nan: Win count = 258 Win ratio = 27.044025157232703
# Epoch 954: err = nan: Win count = 258 Win ratio = 27.015706806282726
# Epoch 955: err = nan: Win count = 258 Win ratio = 26.98744769874477
# Epoch 956: err = nan: Win count = 258 Win ratio = 26.959247648902824
# Epoch 957: err = nan: Win count = 258 Win ratio = 26.931106471816285
# Epoch 958: err = nan: Win count = 258 Win ratio = 26.903023983315954
# Epoch 959: err = nan: Win count = 258 Win ratio = 26.875
# Epoch 960: err = nan: Win count = 258 Win ratio = 26.84703433922997
# Epoch 961: err = nan: Win count = 258 Win ratio = 26.819126819126822
# Epoch 962: err = nan: Win count = 259 Win ratio = 26.895119418483905
# Epoch 963: err = nan: Win count = 259 Win ratio = 26.86721991701245
# Epoch 964: err = nan: Win count = 260 Win ratio = 26.94300518134715
# Epoch 965: err = nan: Win count = 260 Win ratio = 26.91511387163561
# Epoch 966: err = nan: Win count = 260 Win ratio = 26.887280248190283
# Epoch 967: err = nan: Win count = 261 Win ratio = 26.962809917355372
# Epoch 968: err = nan: Win count = 261 Win ratio = 26.93498452012384
# Epoch 969: err = nan: Win count = 262 Win ratio = 27.010309278350515
# Epoch 970: err = nan: Win count = 262 Win ratio = 26.982492276004123
# Epoch 971: err = nan: Win count = 262 Win ratio = 26.954732510288064
# Epoch 972: err = nan: Win count = 262 Win ratio = 26.92702980472765
# Epoch 973: err = nan: Win count = 263 Win ratio = 27.002053388090346
# Epoch 974: err = nan: Win count = 263 Win ratio = 26.974358974358974
# Epoch 975: err = nan: Win count = 263 Win ratio = 26.946721311475407
# Epoch 976: err = nan: Win count = 263 Win ratio = 26.919140225179124
# Epoch 977: err = nan: Win count = 263 Win ratio = 26.89161554192229
# Epoch 978: err = nan: Win count = 263 Win ratio = 26.86414708886619
# Epoch 979: err = nan: Win count = 263 Win ratio = 26.836734693877553
# Epoch 980: err = nan: Win count = 263 Win ratio = 26.809378185524974
# Epoch 981: err = nan: Win count = 263 Win ratio = 26.782077393075355
# Epoch 982: err = nan: Win count = 263 Win ratio = 26.754832146490337
# Epoch 983: err = nan: Win count = 263 Win ratio = 26.727642276422763
# Epoch 984: err = nan: Win count = 264 Win ratio = 26.802030456852794
# Epoch 985: err = nan: Win count = 264 Win ratio = 26.774847870182555
# Epoch 986: err = nan: Win count = 264 Win ratio = 26.74772036474164
# Epoch 987: err = nan: Win count = 264 Win ratio = 26.720647773279353
# Epoch 988: err = nan: Win count = 264 Win ratio = 26.693629929221434
# Epoch 989: err = nan: Win count = 265 Win ratio = 26.767676767676768
# Epoch 990: err = nan: Win count = 265 Win ratio = 26.740665993945512
# Epoch 991: err = nan: Win count = 265 Win ratio = 26.713709677419356
# Epoch 992: err = nan: Win count = 265 Win ratio = 26.686807653575023
# Epoch 993: err = nan: Win count = 265 Win ratio = 26.65995975855131
# Epoch 994: err = nan: Win count = 266 Win ratio = 26.733668341708544
# Epoch 995: err = nan: Win count = 266 Win ratio = 26.706827309236946
# Epoch 996: err = nan: Win count = 266 Win ratio = 26.68004012036108
# Epoch 997: err = nan: Win count = 266 Win ratio = 26.65330661322645
# Epoch 998: err = nan: Win count = 266 Win ratio = 26.626626626626624
# Epoch 999: err = nan: Win count = 266 Win ratio = 26.6
# Epoch 1000: err = nan: Win count = 266 Win ratio = 26.573426573426573
# Model saved in file: C:\Users\JK\강화학습의 이해/model.ckpt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
